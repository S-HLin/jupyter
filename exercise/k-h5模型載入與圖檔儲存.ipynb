# %% [markdown]
# ### h5模型載入與圖檔儲存

# %% [markdown]
# https://zhuanlan.zhihu.com/p/58764438

# %% [markdown]
# https://zouzhen.net/2019/01/16/keras-RetinaNet%E9%97%AE%E9%A2%98%E8%AE%B0%E5%BD%95/

# %%
# import keras_retinanet
from keras_retinanet import models

# %%
model_path ='/dataDisk/myfloder/jupyter/snapshots/resnet50_csv_trans.h5'
#retinanet/resnet50_csv_26.h5
model = models.load_model(model_path) #, backbone_name='resnet50')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /usr/local/lib/python3.5/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
#model = models.convert_model(model)
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# padding_conv1 (ZeroPadding2D)   (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9408        padding_conv1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           bn_conv1[0][0]
# ...

# %%
# 安裝 pydot、graphviz
import pydot
from keras.utils import plot_model
plot_model(model,to_file='retinanet12333.png')

# %% [markdown]
# ### end
