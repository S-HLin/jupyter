# %% [markdown]
# ### 伺服器連結

# %% [markdown]
# https://spacewander.github.io/explore-flask-zh/3-environment.html

# %% [markdown]
# https://www.jianshu.com/p/9d6da9b76d70

# %% [markdown]
# http://www.runoob.com/python3/python3-json.html

# %% [markdown]
# https://www.geeksforgeeks.org/get-post-requests-using-python/

# %% [markdown]
# http://python.jobbole.com/80956/

# %% [markdown]
# https://www.cnblogs.com/shengulong/p/8207179.html

# %% [markdown]
# ### 1

# %% [markdown]
# https://medium.com/@umerfarooq_26378/web-services-in-python-ef81a9067aaf

# %% [markdown]
# #### Flask -python web framework

# %%
from flask import Flask
app = Flask(__name__)
@app.route('/')
def index():
    return "Hello, World!"

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)

# %% [markdown]
# ####  接收json

# %%
from flask import Flask,request
app = Flask(__name__)

@app.route('/postjson', methods=['POST'])
def post():
    print(request.is_json)
    content = request.get_json()
    #print(content)
    print(content['id'])
    print(content['name'])
    return 'JSON posted'

app.run(host='0.0.0.0', port=5000)

# %% [markdown]
# #### 接收image

# %%
from flask import Flask, render_template, request
from flask_uploads import UploadSet, configure_uploads, IMAGES

# %%
#建立應用程序
app = Flask(__name__)
#建立上傳資料夾
photos = UploadSet('photos', IMAGES)
#設定參數
app.config['UPLOADED_PHOTOS_DEST'] = '/dataDisk/myfloder/jupyter/server/img'
#把資料夾設定註冊到app(含上傳模組設定)
configure_uploads(app, photos)

# %%
@app.route('/upload', methods=['GET', 'POST'])

def upload():
    if request.method == 'POST' and 'photo' in request.files:
        filename = photos.save(request.files['photo'])
        return filename  
    return render_template('upload.html')


if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [11/Jun/2019 15:49:32] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jun/2019 15:49:38] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:49:38] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:38] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:38] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:38] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:50] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:52] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:49:52] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:52] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:52] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:52] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:52] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:49:53] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:06] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:54:06] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:06] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:06] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:11] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:11] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:11] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:11] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:43] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:54:43] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:43] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:43] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:43] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:43] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:54:44] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:21] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:21] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:21] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:21] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:21] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:21] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:22] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
# ...
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:29] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2328, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2314, in wsgi_app
#     response = self.handle_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1760, in handle_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 2311, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1834, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1737, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.5/dist-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1832, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.5/dist-packages/flask/app.py", line 1818, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-3-387413b18589>", line 7, in upload
#
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 134, in render_template
#     return _render(ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "/usr/local/lib/python3.5/dist-packages/jinja2/loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 58, in get_source
#     return self._get_source_fast(environment, template)
#   File "/usr/local/lib/python3.5/dist-packages/flask/templating.py", line 86, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload.html
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=jquery.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:30] "GET /upload?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2019 15:55:57] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# https://blog.csdn.net/gqv2009/article/details/79901292

# %%
sudo netstat -ltnp

# %% [markdown]
# #### html file

# %%
<html>
<head>
    <title>Upload</title>
</head>
<body>
<form method=POST enctype=multipart/form-data action="{{ url_for('upload') }}">
    <input type=file name=photo>
    <input type="submit">
</form>
</body>
</html>

# %% [markdown]
# ### 2

# %% [markdown]
# https://hackmd.io/s/BJPLnPHJX

# %%
from flask import Flask
from flask_uploads import UploadSet, IMAGES, configure_uploads
from flask import request

# %%
app = Flask(__name__)
app.config['UPLOADED_DEF_DEST'] = '/dataDisk/myfloder/jupyter/img'

abc = UploadSet(name='def', extensions=IMAGES)
configure_uploads(app, abc)

# %%
html = '''
<!DOCTYPE html>
<html lang="en">
<h1>測試上傳</h1>
<form method=post enctype=multipart/form-data>
<input type=file name=in_abc>
<input type=submit value=Upload>
</form>
</html>
'''

# %%
@app.route('/uploads/', methods=['GET', 'POST'])
def uploads():
    if request.method == 'POST' and 'in_abc' in request.files:
        filename = abc.save(request.files['in_abc'])
        print(filename)
        file_url = abc.url(filename)
        print(file_url)
    return html


if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# http://python.jobbole.com/80956/

# %%
app = Flask(__name__)
 
@app.route('/dataDisk/myfloder/jupyter/upload/')
def hello():
    #print('its work')
    return "Hello World!"

hello()

# %%
# This is our decorator
def simple_decorator(f):
    # This is the new function we're going to return
    # This function will be used in place of our original definition
    def wrapper():
        print("Entering Function")
        f()
        print("Exited Function")
 
    return wrapper
 
@simple_decorator 
def hello():
    print('Hello World')

    
def hii():
    print('hii')    
    
 
hello()
hii()

# %%
class NotFlask():
    def __init__(self):
        self.routes={}
    def route(self,route_str):
        def decorator(f):
            self.routes[route_str]=f
            return f
        return decorator
    def serve(self,path):
        view_function =self.routes.get(path)
        if view_function:
            return view_function()
        else:
            raise ValueError('Route "{}" has not been registered'.format(path))
            
app = NotFlask()

@app.route('/')
def hello():
    return 'hello world!'

# %%
def decorator_factory(enter_message, exit_message):
    # We're going to return this decorator
    def simple_decorator(f):
        def wrapper():
            print(enter_message)
            f()
            print(exit_message)
 
        return wrapper
 
    return simple_decorator

@decorator_factory("Start", "End")
def hello():
    print("Hello World")
 
hello()

# %%
class NotFlask():
    def __init__(self):
        self.routes = {}
 
    def route(self, route_str):
        def decorator(f):
            self.routes[route_str] = f
            return f 
        return decorator
 
app = NotFlask()
 
@app.route("/")
def hello():
    return "Hello World!1111"

app.routes

# %%
app=Flask(__name__)
@app.route('/')
def hello():
    return 'hello world'

# %% [markdown]
# ### 3

# %%
import os
from flask import Flask, request, redirect, url_for
from werkzeug.utils import secure_filename
from flask import send_from_directory
# from werkzeug import SharedDataMiddleware

# %%
UPLOAD_FOLDER ='/dataDisk/myfloder/jupyter/img'
ALLOWED_EXTENSIONS = set(['txt', 'pdf', 'png', 'jpg', 'jpeg', 'gif'])

app = Flask(__name__)
app.config['UPLOAD_FOLDER']=UPLOAD_FOLDER

# %%
def allowed_file(filename):
    return '.' in filename and \
           filename.rsplit('.', 1)[1].lower() in ALLOWED_EXTENSIONS

# %%
@app.route('/', methods=['GET', 'POST'])
def upload_file():
    if request.method == 'POST':
        # check if the post request has the file part
        if 'file' not in request.files:
            # flash('No file part')
            return redirect(request.url)
        file = request.files['file']
        # if user does not select file, browser also
        # submit a empty part without filename
        if file.filename == '':
            # flash('No selected file')
            return redirect(request.url)
        if file and allowed_file(file.filename):
            filename = secure_filename(file.filename)
            file.save(os.path.join(app.config['UPLOAD_FOLDER'], filename))
            return redirect(url_for('uploaded_file',
                                    filename=filename))
    return '''
    <!doctype html>
    <title>Upload new File</title>
    <h1>Upload new File</h1>
    <form method=post enctype=multipart/form-data>
      <p><input type=file name=file>
         <input type=submit value=Upload>
    </form>
    '''

# %%
@app.route('/uploads/<filename>')
def uploaded_file(filename):
    return send_from_directory(app.config['UPLOAD_FOLDER'],
                               filename)


if __name__ == '__main__':
    app.run(debug=True)

# app.add_url_rule('/uploads/<filename>', 'uploaded_file',
#                  build_only=True)
# app.wsgi_app = SharedDataMiddleware(app.wsgi_app, {
#     '/uploads':  app.config['UPLOAD_FOLDER']
# })
